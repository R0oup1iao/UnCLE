# %%
import numpy as np 
import pandas as pd
import os

data_path = "/home/yhy/my_project/UnCLE/data/real/data/SD"
data = np.load(os.path.join(data_path, "flowsd.npz"))['data'][..., 0]
coord = pd.read_csv(os.path.join(data_path, "sd_meta.csv"))[['Lng', 'Lat']].values

# %%
os.makedirs("/home/yhy/my_project/UnCLE/data/real/SD", exist_ok=True)

# %%
np.save("/home/yhy/my_project/UnCLE/data/real/SD/data_0.npy", data)
np.save("/home/yhy/my_project/UnCLE/data/real/SD/coords_0.npy", coord)
